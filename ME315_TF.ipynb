# %% [markdown]
# <a href="https://colab.research.google.com/github/GZanareli/ManipulacaoBancoDados/blob/main/ME315_TF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ME315 - Manipulação de Bancos de Dados
# ---
# ## Análise de performance e facilidade com aplicações em amostragem baseada em endereços
#
# ---
# Orientador: Prof. Carlos Trucíos
#
# Alunos: Gustavo Zanareli Andrade (185666) & Luciano Matheus Floriano (277195)

# %% [markdown]
# ## Configuração dos Ambientes Julia, R e Python
#
# ---
# ```
# # Configuração do ambiente Julia
# using DataFrames
# using CSV
# using Statistics
# using BenchmarkTools
# using RCall
# using PyCall
# using Plots
# using Random
# gr()
# ```

# %% [markdown]
# Configuração do Ambiente R e Python
#
# ---
#
# ```
# # Configurar R e Python para comparação
# R"""
# library(dplyr)
# library(readr)
# library(microbenchmark)
# """
#
# py"""
# import pandas as pd
# import numpy as np
# import time
# """
# ```
